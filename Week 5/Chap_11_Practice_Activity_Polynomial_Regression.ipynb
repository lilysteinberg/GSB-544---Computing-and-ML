# %% [markdown]
# ---
# title: "Practice Activity 6.1: Polynomial Regression"
# author: Lily
# format:
#     html:
#         embed-resources: true
#         code-line-numbers: true
# ---
#
# **GitHub Repository**: <https://github.com/lilysteinberg/GSB-544---Computing-and-ML/tree/main/Week%205>

# %% [markdown]
# # Palmer Penguins Modeling
#
# Import the Palmer Penguins dataset and print out the first few rows.
#
# Suppose we want to predict `bill_depth_mm` using the other variables in the dataset.
#
# Which variables would we need to **dummify**?

# %%
# General libraries
import numpy as np
import pandas as pd

# Penguin data
# !pip install palmerpenguins
from palmerpenguins import load_penguins
penguins = load_penguins()

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
# Need to dummify species, island, sex, and year.

# %% [markdown]
# Let's use `bill_length_mm` to predict `bill_depth_mm`. Prepare your data and fit the following models on the entire dataset:
#
# * Simple linear regression (e.g. straight-line) model
# * Quadratic (degree 2 polynomial) model
# * Cubic (degree 3 polynomial) model
# * Degree 10 polynomial model
#
# Make predictions for each model and plot your fitted models on the scatterplot.

# %%
from sklearn.linear_model import LinearRegression

# %%
penguins = penguins.dropna()

# %%
# Linear
bill_lin_model = LinearRegression()
bill_lin_model.fit(
    X=penguins[["bill_length_mm"]],
    y=penguins["bill_depth_mm"]
)
# Out:
# LinearRegression()

# %%
# plotting
X_new = pd.DataFrame()
X_new["bill_length_mm"] = np.linspace(30, 60, num=1000)
y_new_ = pd.Series(
    bill_lin_model.predict(X_new),
    index=X_new["bill_length_mm"]
)

penguins.plot.scatter(x="bill_length_mm", y="bill_depth_mm")
y_new_.plot.line(c = "orange")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# Quadratic

# add column
penguins["bill_length_squared"] = penguins['bill_length_mm'] **2

# model
square_model = LinearRegression()
square_model.fit(
    X=penguins[["bill_length_mm", "bill_length_squared"]],
    y=penguins["bill_depth_mm"]
)
# Out:
# LinearRegression()

# %%
# plotting
X_new = pd.DataFrame()
X_new["bill_length_mm"] = np.linspace(30, 60, num=1000)
X_new["bill_length_squared"] = X_new["bill_length_mm"] ** 2
y_new_ = pd.Series(
    square_model.predict(X_new),
    index=X_new["bill_length_mm"]
)

penguins.plot.scatter(x="bill_length_mm", y="bill_depth_mm")
y_new_.plot.line(c = "orange")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# Cubic

# add column
penguins["bill_length_cubed"] = penguins['bill_length_mm'] **3

# model
cube_model = LinearRegression()
cube_model.fit(
    X=penguins[["bill_length_mm", "bill_length_squared", "bill_length_cubed"]],
    y=penguins["bill_depth_mm"]
)
# Out:
# LinearRegression()

# %%
# plotting
X_new = pd.DataFrame()
X_new["bill_length_mm"] = np.linspace(30, 60, num=1000)
X_new["bill_length_squared"] = X_new["bill_length_mm"] ** 2
X_new["bill_length_cubed"] = X_new["bill_length_mm"] ** 3
y_new_ = pd.Series(
    cube_model.predict(X_new),
    index=X_new["bill_length_mm"]
)

penguins.plot.scatter(x="bill_length_mm", y="bill_depth_mm")
y_new_.plot.line(c = "orange")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# degree 10

# add columns
penguins["bill_length_exp4"] = penguins['bill_length_mm'] **4
penguins["bill_length_exp5"] = penguins['bill_length_mm'] **5
penguins["bill_length_exp6"] = penguins['bill_length_mm'] **6
penguins["bill_length_exp7"] = penguins['bill_length_mm'] **7
penguins["bill_length_exp8"] = penguins['bill_length_mm'] **8
penguins["bill_length_exp9"] = penguins['bill_length_mm'] **9
penguins["bill_length_exp10"] = penguins['bill_length_mm'] **10

# model
tenthdegree_model = LinearRegression()
tenthdegree_model.fit(
    X=penguins[["bill_length_mm", "bill_length_squared", "bill_length_cubed", "bill_length_exp4", "bill_length_exp5", "bill_length_exp6", "bill_length_exp7", "bill_length_exp8", "bill_length_exp9", "bill_length_exp10"]],
    y=penguins["bill_depth_mm"]
)
# Out:
# LinearRegression()

# %%
# plotting
X_new = pd.DataFrame()
X_new["bill_length_mm"] = np.linspace(30, 60, num=1000)
X_new["bill_length_squared"] = X_new["bill_length_mm"] ** 2
X_new["bill_length_cubed"] = X_new["bill_length_mm"] ** 3
X_new["bill_length_exp4"] = X_new["bill_length_mm"] ** 4
X_new["bill_length_exp5"] = X_new["bill_length_mm"] ** 5
X_new["bill_length_exp6"] = X_new["bill_length_mm"] ** 6
X_new["bill_length_exp7"] = X_new["bill_length_mm"] ** 7
X_new["bill_length_exp8"] = X_new["bill_length_mm"] ** 8
X_new["bill_length_exp9"] = X_new["bill_length_mm"] ** 9
X_new["bill_length_exp10"] = X_new["bill_length_mm"] ** 10
y_new_ = pd.Series(
    tenthdegree_model.predict(X_new),
    index=X_new["bill_length_mm"]
)

penguins.plot.scatter(x="bill_length_mm", y="bill_depth_mm")
y_new_.plot.line(c = "orange")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
# alternative plotting method:
#penguins["bill_depth_predict"] = bill_lin_model.predict(penguins[["bill_length_mm"]])
#penguins

### further instructions:
# gives chart including bill length (x), predicted y, and actual bill_depth_mm (actual y)
# pivot so bill length is one column and then bill depth is another with categories predicted and actual
# plot that

# %% [markdown]
# * Are any of the models above underfitting the data? If so, which ones and how can you tell?
# * Are any of thhe models above overfitting the data? If so, which ones and how can you tell?
# * Which of the above models do you think fits the data best and why?

# %% [markdown]
# The linear model is likely underfitting the data because it does not account for the pattern of higher-density clusters in any way.
#
# The polynomial to the tenth degree is likely overfitting the data, especially visible towards the 55-60 range of the data where the line curves to accomodate only 2 datapoints.
#
# I think the quadratic and cubic models fit the best because they follow the pattern of higher-density clusters. Further evaluation should be performed to choose between them.
